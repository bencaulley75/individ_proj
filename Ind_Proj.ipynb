# %% [markdown]
# <a href="https://colab.research.google.com/github/bencaulley75/individ_proj/blob/main/Ind_Proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/mcd.csv')

# %%
df.head(10)
# Out:
#                             name serving_size  \
# 0                  Black Coffee®        200ml
# 1  Butter Chicken Grilled Burger         153g
# 2   Butter Paneer Grilled Burger         142g
# 3                   Cheesy Fries         150g
# 4          Chicken Maharaja Mac®         296g
# 5             Chicken McNuggets®         64g
# 6             Chicken McNuggets®         96g
# 7             Chicken McNuggets®         320g
# 8             Chicken McNuggets®        144g
# 9           Cold Coffee Mcfloat®        270ml
#
#                                          ingredients  \
# 0                                                NaN
# 1  Premium grilled chicken patty, Shredded onion,...
# 2  Mildly spiced grilled paneer patty, Shredded o...
# 3                 Salted Fries, Smoky Chipotle Sauce
# 4  Maharaja bun crown, Haberno sauce, Shredded le...
# 5                                      Chicken bites
# 6                                      Chicken bites
# ...

# %%
plt.figure()
# plt.bar(df['name'], df['protein'], label='Protein')
# plt.bar(df['name'], df['total_fat'], label='Total Fat')
plt.bar(df['name'], df['carbs'], label='Carbohydrates')
plt.xlabel('Food Item')
plt.ylabel('Content')
plt.title('Macronutrient Composition')
plt.xticks(rotation=90)
_ = plt.legend()

# %%
plt.figure()
# plt.bar(df['name'], df['protein'], label='Protein')
plt.bar(df['name'], df['total_fat'], label='Total Fat')
plt.xlabel('Food Item')
plt.ylabel('Content')
plt.title('Macronutrient Composition')
plt.xticks(rotation=90)
_ = plt.legend()

# %%
plt.figure()
plt.bar(df['name'], df['protein'], label='Protein')
plt.xlabel('Food Item')
plt.ylabel('Content')
plt.title('Macronutrient Composition')
plt.xticks(rotation=90)
_ = plt.legend()

# %%
plt.figure()
plt.bar(df['name'], df['energy'], label='Energy')
plt.xlabel('Food Item')
plt.ylabel('Content')
plt.title('Macronutrient Composition')
plt.xticks(rotation=90)
_ = plt.legend()

# %%
#  energy vs protein

# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='energy', y='protein', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
